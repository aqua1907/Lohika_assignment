# %%
from main import main

# %%
actions = ["поклав", "з'їв", "забрав"]
fruits = ["апельсин", "яблуко", "мандарин", "груша"]

ex1 = """На столі лежить 2 яблука, 3 апельсини, 1 груша та 3 мандарини. 
Хлопчик поклав на стіл 2 яблука, і з'їв 1 мандарин і 1 грушу, 
при цьому він ще забрав 2 апельсини. Скільки всього фруктів з'їв хлопчик? 
Скільки залишилось мандарин та апельсин на столі? 
Скільки фруктів поклав хлопчик на стіл? 
Скільки яблук залишилось?"""

main(ex1, fruits, actions)
# Out:
# Відповідь №1: Хлопчик з'їв 2 фруктів
# Відповідь №2: На столі залишилось 1 апельсин 3 мандарин
# Відповідь №3: Хлопчик поклав 2 фруктів
# Відповідь №4: На столі залишилось 2 яблуко

# %%
actions = ["з'їв"]
fruits = ["апельсин", "груша"]

ex1 = """На столі було 10 апельсинів та 3 груші. Хлопчик з'їв 3 апельсини. 
        Скільки всього фруктів залишилось на столі? """

main(ex1, fruits, actions)
# Out:
# Відповідь №1: На столі залишилось 10 фруктів

# %%
actions = ["з'їв"]
fruits = ["яблуко", "мандарин", "апельсини"]

ex1 = """3 апельсини 5 яблук,10 мандарин та 4 олівці лежали на столі. 
        Хлопчик з'їв 4 мандарини та 2 апельсини. 
        Скільки всього фруктів з'їв хлопчик? 
        Скільки залишилось мандарин на столі?"""

main(ex1, fruits, actions)
# Out:
# Відповідь №1: Хлопчик з'їв 6 фруктів
# Відповідь №2: На столі залишилось 6 мандарин

# %%
actions = ["поклав", "забрав"]
fruits = ["апельсин", "яблуко", "мандарин", "груша"]

ex1 = """На столі лежить 2 яблука, 3 апельсини, 1 груша та 3 мандарини. 
Хлопчик поклав на стіл 2 яблука, і з'їв 1 мандарин і 1 грушу, 
при цьому він ще забрав 2 апельсини. Скільки всього фруктів з'їв хлопчик? 
Скільки залишилось мандарин та апельсин на столі? 
Скільки фруктів поклав хлопчик на стіл? 
Скільки яблук залишилось? Скільки фруктів?"""

main(ex1, fruits, actions)
# Out:
# Відповідь №1: Питання №1 описано в умові направильно
# Відповідь №2: На столі залишилось 1 апельсин 3 мандарин
# Відповідь №3: Хлопчик поклав 4 фруктів
# Відповідь №4: На столі залишилось 2 яблуко
# Відповідь №5: Питання №5 описано в умові направильно
